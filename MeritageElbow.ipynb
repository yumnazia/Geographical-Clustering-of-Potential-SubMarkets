# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_excel('C:/Meritage Project/Merged File with VDL information.xlsx') #Reading the Data file
df.head()
# Out:
#    ZIP Code  2018 Total Crime Index  2018 Total Daytime Population  \
# 0     85003                     305                          44327
# 1     85004                     349                          48170
# 2     85006                     243                          38744
# 3     85007                     277                          43061
# 4     85008                     203                          62299
#
#    2018 Daytime Pop: Workers  2018 Education: Associate's Degree  \
# 0                      39131                                 302
# 1                      44533                                 200
# 2                      20958                                 810
# 3                      33169                                 363
# 4                      30088                                1815
#
#    2018 Education: Some College/No Degree  \
# 0                                    1673
# 1                                     817
# ...

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(3,12))

visualizer.fit(df)    # Running the Elbow method to find the optimal number of clusters
visualizer.poof()

# %%
from sklearn.cluster import KMeans

kmeans=KMeans(n_clusters=5)    #Doing the Kmeans for 5 Clusters
kmeans.fit(df)

kmeans.labels_
# Out:
# array([4, 4, 1, 4, 1, 1, 0, 4, 4, 1, 4, 1, 0, 1, 4, 4, 4, 4, 4, 1, 1, 0,
#        1, 1, 4, 1, 1, 1, 1, 1, 1, 1, 1, 4, 0, 0, 4, 1, 1, 0, 0, 4, 0, 4,
#        4, 1, 1, 1, 1, 1, 1, 1, 1, 1, 4, 1, 1, 1, 1, 1, 4, 1, 1, 4, 1, 1,
#        1, 1, 1, 1, 4, 4, 4, 4, 1, 4, 4, 4, 4, 0, 4, 4, 3, 0, 2, 4, 0, 2,
#        0, 2, 0, 4, 2, 0, 1, 1, 4, 0, 4, 4, 4, 4, 0, 1, 1, 1, 1, 4, 1, 1,
#        4, 4, 1, 1, 0, 4, 4, 4, 4, 1, 1, 1, 4, 4, 1, 1, 4, 4, 2, 4, 4, 4,
#        0, 4, 4, 4, 1, 4, 4, 4])

# %%
x=kmeans.predict(df)
x
# Out:
# array([4, 4, 1, 4, 1, 1, 0, 4, 4, 1, 4, 1, 0, 1, 4, 4, 4, 4, 4, 1, 1, 0,
#        1, 1, 4, 1, 1, 1, 1, 1, 1, 1, 1, 4, 0, 0, 4, 1, 1, 0, 0, 4, 0, 4,
#        4, 1, 1, 1, 1, 1, 1, 1, 1, 1, 4, 1, 1, 1, 1, 1, 4, 1, 1, 4, 1, 1,
#        1, 1, 1, 1, 4, 4, 4, 4, 1, 4, 4, 4, 4, 0, 4, 4, 3, 0, 2, 4, 0, 2,
#        0, 2, 0, 4, 2, 0, 1, 1, 4, 0, 4, 4, 4, 4, 0, 1, 1, 1, 1, 4, 1, 1,
#        4, 4, 1, 1, 0, 4, 4, 4, 4, 1, 1, 1, 4, 4, 1, 1, 4, 4, 2, 4, 4, 4,
#        0, 4, 4, 4, 1, 4, 4, 4])

# %%
df['new_val']=x

# %%
df.head()
# Out:
#    ZIP Code  2018 Total Crime Index  2018 Total Daytime Population  \
# 0     85003                     305                          44327
# 1     85004                     349                          48170
# 2     85006                     243                          38744
# 3     85007                     277                          43061
# 4     85008                     203                          62299
#
#    2018 Daytime Pop: Workers  2018 Education: Associate's Degree  \
# 0                      39131                                 302
# 1                      44533                                 200
# 2                      20958                                 810
# 3                      33169                                 363
# 4                      30088                                1815
#
#    2018 Education: Some College/No Degree  \
# 0                                    1673
# 1                                     817
# ...

# %%
df.to_excel("df.xlsx")   #To download the new file with cluster information
